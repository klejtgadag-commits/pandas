# %%
#input library
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
df=pd.read_csv("/content/matches.csv") # loding dataset
df  # df is object name
# Out:
#            id   season        city        date   match_type  player_of_match  \
# 0      335982  2007/08   Bangalore  2008-04-18       League      BB McCullum
# 1      335983  2007/08  Chandigarh  2008-04-19       League       MEK Hussey
# 2      335984  2007/08       Delhi  2008-04-19       League      MF Maharoof
# 3      335985  2007/08      Mumbai  2008-04-20       League       MV Boucher
# 4      335986  2007/08     Kolkata  2008-04-20       League        DJ Hussey
# ...       ...      ...         ...         ...          ...              ...
# 1090  1426307     2024   Hyderabad  2024-05-19       League  Abhishek Sharma
# 1091  1426309     2024   Ahmedabad  2024-05-21  Qualifier 1         MA Starc
# 1092  1426310     2024   Ahmedabad  2024-05-22   Eliminator         R Ashwin
# 1093  1426311     2024     Chennai  2024-05-24  Qualifier 2    Shahbaz Ahmed
# 1094  1426312     2024     Chennai  2024-05-26        Final         MA Starc
#
# ...

# %%
#top 5 rows in the dataset
df.head()#in the paranthesis we need to give value how many no of rows we need
# Out:
#        id   season        city        date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
# 2  335984  2007/08       Delhi  2008-04-19     League     MF Maharoof
# 3  335985  2007/08      Mumbai  2008-04-20     League      MV Boucher
# 4  335986  2007/08     Kolkata  2008-04-20     League       DJ Hussey
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                            Feroz Shah Kotla             Delhi Daredevils
# 3                            Wankhede Stadium               Mumbai Indians
# 4                                Eden Gardens        Kolkata Knight Riders
#
#                          team2                  toss_winner toss_decision  \
# ...

# %%
# last 5 rows
df.tail(7)# it returns bottoms 5 rows by default if need we can pass in brackets
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1095 entries, 0 to 1094
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               1095 non-null   int64
#  1   season           1095 non-null   object
#  2   city             1044 non-null   object
#  3   date             1095 non-null   object
#  4   match_type       1095 non-null   object
#  5   player_of_match  1090 non-null   object
#  6   venue            1095 non-null   object
#  7   team1            1095 non-null   object
#  8   team2            1095 non-null   object
#  9   toss_winner      1095 non-null   object
#  10  toss_decision    1095 non-null   object
#  11  winner           1090 non-null   object
#  12  result           1095 non-null   object
#  13  result_margin    1076 non-null   float64
#  14  target_runs      1092 non-null   float64
#  15  target_overs     1092 non-null   float64
# ...

# %%
len(df)#it returns no of rows
# Out:
# 1095

# %% [markdown]
# ##data cleaning
# ##process for dATA cleaning
# > looking for duplicates and remove them
#
# >standardization
#
# >deal with null and empty values
#
# >remove unwanted columns

# %%
df.duplicated().sum()#if we get zero no duplicates
# Out:
# np.int64(0)

# %%
df.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'match_type', 'player_of_match',
#        'venue', 'team1', 'team2', 'toss_winner', 'toss_decision', 'winner',
#        'result', 'result_margin', 'target_runs', 'target_overs', 'super_over',
#        'method', 'umpire1', 'umpire2'],
#       dtype='object')

# %% [markdown]
#  ####deal with null and empty values

# %%
df.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'match_type', 'player_of_match',
#        'venue', 'team1', 'team2', 'toss_winner', 'toss_decision', 'winner',
#        'result', 'result_margin', 'target_runs', 'target_overs', 'super_over',
#        'umpire1', 'umpire2'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# id                    0
# season                0
# city                 51
# date                  0
# match_type            0
# player_of_match       5
# venue                 0
# team1                 0
# team2                 0
# toss_winner           0
# toss_decision         0
# winner                5
# result                0
# result_margin        19
# target_runs           3
# target_overs          3
# super_over            0
# method             1074
# umpire1               0
# umpire2               0
# dtype: int64

# %%
### accessing unwanted columns
df[['toss_decision','winner']]
##df.id ## here we are accessing id columnbut not good practice
# Out:
#      toss_decision                       winner
# 0            field        Kolkata Knight Riders
# 1              bat          Chennai Super Kings
# 2              bat             Delhi Daredevils
# 3              bat  Royal Challengers Bangalore
# 4              bat        Kolkata Knight Riders
# ...            ...                          ...
# 1090           bat          Sunrisers Hyderabad
# 1091           bat        Kolkata Knight Riders
# 1092         field             Rajasthan Royals
# 1093         field          Sunrisers Hyderabad
# 1094           bat        Kolkata Knight Riders
#
# [1028 rows x 2 columns]

# %%
df.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'match_type', 'player_of_match',
#        'venue', 'team1', 'team2', 'toss_winner', 'toss_decision', 'winner',
#        'result', 'result_margin', 'target_runs', 'target_overs', 'super_over',
#        'umpire1', 'umpire2'],
#       dtype='object')

# %% [markdown]
# ###droping rows with null values

# %%
df.shape
# Out:
# (1028, 19)

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# id                 0
# season             0
# city               0
# date               0
# match_type         0
# player_of_match    0
# venue              0
# team1              0
# team2              0
# toss_winner        0
# toss_decision      0
# winner             0
# result             0
# result_margin      0
# target_runs        0
# target_overs       0
# super_over         0
# umpire1            0
# umpire2            0
# dtype: int64

# %%
df.shape
# Out:
# (1028, 19)

# %%
df.drop(columns='city',inplace=True)

# %%
df.columns
# Out:
# Index(['id', 'season', 'date', 'match_type', 'player_of_match', 'venue',
#        'team1', 'team2', 'toss_winner', 'toss_decision', 'winner', 'result',
#        'result_margin', 'target_runs', 'target_overs', 'super_over', 'umpire1',
#        'umpire2'],
#       dtype='object')

# %%
df.describe()
# Out:
#                  id  result_margin  target_runs  target_overs
# count  1.028000e+03    1028.000000  1028.000000   1028.000000
# mean   8.957829e+05      17.026265   165.656615     19.758949
# std    3.720568e+05      21.569306    33.605098      1.562059
# min    3.359820e+05       1.000000    43.000000      5.000000
# 25%    5.483178e+05       6.000000   146.000000     20.000000
# 50%    9.809380e+05       8.000000   166.000000     20.000000
# 75%    1.254078e+06      20.000000   187.000000     20.000000
# max    1.426312e+06     146.000000   288.000000     20.000000

# %%
df.iloc[0,2]##to acess specific row and column
# Out:
# '2008-04-18'

# %%
df.columns
# Out:
# Index(['id', 'season', 'date', 'match_type', 'player_of_match', 'venue',
#        'team1', 'team2', 'toss_winner', 'toss_decision', 'winner', 'result',
#        'result_margin', 'target_runs', 'target_overs', 'super_over', 'umpire1',
#        'umpire2'],
#       dtype='object')

# %%
##slicing
df.iloc[0,0:3]
# Out:
# id            335982
# season       2007/08
# date      2008-04-18
# Name: 0, dtype: object

# %%
df.loc[3,["team1","team2"]]
# Out:
# team1                 Mumbai Indians
# team2    Royal Challengers Bangalore
# Name: 3, dtype: object

# %%
df.head()
# Out:
#        id   season        date match_type player_of_match  \
# 0  335982  2007/08  2008-04-18     League     BB McCullum
# 1  335983  2007/08  2008-04-19     League      MEK Hussey
# 2  335984  2007/08  2008-04-19     League     MF Maharoof
# 3  335985  2007/08  2008-04-20     League      MV Boucher
# 4  335986  2007/08  2008-04-20     League       DJ Hussey
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                            Feroz Shah Kotla             Delhi Daredevils
# 3                            Wankhede Stadium               Mumbai Indians
# 4                                Eden Gardens        Kolkata Knight Riders
#
#                          team2                  toss_winner toss_decision  \
# 0        Kolkata Knight Riders  Royal Challengers Bangalore         field
# ...
